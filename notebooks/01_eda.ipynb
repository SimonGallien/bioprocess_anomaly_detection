# %%
import sys
sys.path.append("..")

# %%
from src.get_data import download_data

# %%
download_data()
# Out:
# ✅ Données téléchargées dans le cache : /home/simon/.cache/kagglehub/datasets/stephengoldie/big-databiopharmaceutical-manufacturing/versions/1
# 🎯 2 fichiers CSV trouvés. Copie en cours...
#    └─ 📁 Copié : 100_Batches_IndPenSim_V3.csv
#    └─ 📁 Copié : 100_Batches_IndPenSim_Statistics.csv
#
# 🎉 Initialisation terminée ! Les données sont dans : /home/simon/projects/bioprocess_anomaly_detection/data

# %%
import pandas as pd

# %%
df = pd.read_csv("../data/100_Batches_IndPenSim_Statistics.csv")
df.head()
# Out:
#    Batch ref  Penicllin_harvested_during_batch(kg)  \
# 0          1                             1066400.0
# 1          2                              985910.0
# 2          3                             1416100.0
# 3          4                              815700.0
# 4          5                             1128500.0
#
#    Penicllin_harvested_end_of_batch (kg)  Penicllin_yield_total (kg)  \
# 0                              1720000.0                   2786400.0
# 1                              1340100.0                   2326000.0
# 2                              1259200.0                   2675300.0
# 3                              1071000.0                   1886700.0
# 4                              2434400.0                   3562900.0
#
#    Fault ref(0-NoFault 1-Fault)
# 0                             0
# 1                             0
# 2                             0
# 3                             0
# 4                             0
